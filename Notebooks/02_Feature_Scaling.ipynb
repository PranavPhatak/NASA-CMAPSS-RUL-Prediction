# %%
import joblib
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
WITHOUT_CONSTANT_TRAIN = "../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_training(removed_the_sensor).csv"
WITHOUT_CONSTANT_VAL = "../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_validation(removed_the_sensor).csv"

WITHOUT_CONSTANT_TRAIN_SCALED = "../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_training_scaled(removed_the_sensor).csv"
WITHOUT_CONSTANT_VAL_SCALED = "../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_validation_scaled(removed_the_sensor).csv"

WITHOUT_CONSTANT_SCALER = "../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_scaler(removed_the_sensor).pkl"

# %%
ID_COLUMNS = ["unit_id", "cycle"]
TARGET_COLUMN = "RUL"

# %%
def scale_dataset(train_path, val_path, train_output_path, val_output_path, scaler_output_path):
    train_df = pd.read_csv(train_path)
    val_df = pd.read_csv(val_path)

    print("Training:", train_df.shape)
    print("Validation:", val_df.shape)

    train_df = train_df.sort_values(
        by=["unit_id", "cycle"]
    ).reset_index(drop=True)

    val_df = val_df.sort_values(
        by=["unit_id", "cycle"]
    ).reset_index(drop=True)

    feature_columns = [
        column
        for column in train_df.columns
        if column not in ID_COLUMNS + [TARGET_COLUMN]
    ]

    print("\nFeature columns:\n", feature_columns)
    print("\nNumber of features:", len(feature_columns))

    scaler = MinMaxScaler()
    train_df[feature_columns] = scaler.fit_transform(train_df[feature_columns])
    val_df[feature_columns] = scaler.transform(val_df[feature_columns])

    train_df.to_csv(train_output_path, index=False)
    val_df.to_csv(val_output_path, index=False)

    joblib.dump(scaler, scaler_output_path)

    print("\nScaled dataset shapes:")
    print("Training:", train_df.shape)
    print("Validation:", val_df.shape)

    print("\nExample scaled training data:")
    print(train_df.head())

    print("\nExample scaled validation data:")
    print(val_df.head())

    print("\nScaler saved to:")
    print(scaler_output_path)

    print("\nTraining dataset saved to:")
    print(train_output_path)

    print("\nValidation dataset saved to:")
    print(val_output_path)

# %%
scale_dataset(
    train_path=WITHOUT_CONSTANT_TRAIN,
    val_path=WITHOUT_CONSTANT_VAL,

    train_output_path=WITHOUT_CONSTANT_TRAIN_SCALED,
    val_output_path=WITHOUT_CONSTANT_VAL_SCALED,

    scaler_output_path=WITHOUT_CONSTANT_SCALER
)
# Out:
# Training: (16138, 21)
# Validation: (4493, 21)
#
# Feature columns:
#  ['setting_1', 'setting_2', 'setting_3', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_6', 'sensor_7', 'sensor_8', 'sensor_9', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_17', 'sensor_20', 'sensor_21']
#
# Number of features: 18
#
# Scaled dataset shapes:
# Training: (16138, 21)
# Validation: (4493, 21)
#
# Example scaled training data:
#    unit_id  cycle  setting_1  setting_2  setting_3  sensor_2  sensor_3  \
# 0        1      1   0.456647   0.166667        0.0  0.141276  0.404583
# 1        1      2   0.606936   0.250000        0.0  0.242736  0.453500
# 2        1      3   0.248555   0.750000        0.0  0.304228  0.365126
# 3        1      4   0.537572   0.500000        0.0  0.304228  0.245140
# 4        1      5   0.387283   0.333333        0.0  0.310377  0.246524
#
#    sensor_4  sensor_6  sensor_7  ...  sensor_9  sensor_11  sensor_12  \
# 0  0.273296  0.740741  0.775474  ...  0.134005   0.339248   0.692962
# 1  0.315083  0.740741  0.663074  ...  0.123934   0.351278   0.829964
# 2  0.332522  0.740741  0.757048  ...  0.166071   0.218947   0.860899
# 3  0.294189  0.740741  0.792058  ...  0.149634   0.134737   0.958126
# 4  0.365754  0.740741  0.709139  ...  0.176570   0.224962   0.810076
#
#    sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21  RUL
# 0   0.130882   0.223971   0.313824   0.331839   0.744849   0.757736  125
# 1   0.204412   0.184708   0.360984   0.331839   0.697306   0.764033  125
# 2   0.145588   0.194289   0.307306   0.152466   0.657686   0.655341  125
# 3   0.219118   0.197594   0.117133   0.331839   0.602219   0.695998  125
# 4   0.160294   0.197428   0.351782   0.421525   0.618067   0.737750  125
#
# [5 rows x 21 columns]
#
# Example scaled validation data:
#    unit_id  cycle  setting_1  setting_2  setting_3  sensor_2  sensor_3  \
# 0       81      1   0.208092   0.750000        0.0  0.145888  0.382189
# 1       81      2   0.630058   0.666667        0.0  0.333436  0.297738
# 2       81      3   0.468208   0.916667        0.0  0.302690  0.301660
# 3       81      4   0.491329   0.500000        0.0  0.259646  0.497098
# 4       81      5   0.635838   0.666667        0.0  0.567102  0.395572
#
#    sensor_4  sensor_6  sensor_7  ...  sensor_9  sensor_11  sensor_12  \
# 0  0.332390  0.740741  0.732910  ...  0.159665   0.276391   0.836924
# 1  0.352955  0.740741  0.718168  ...  0.177859   0.192180   0.832505
# 2  0.164089  0.740741  0.640778  ...  0.150971   0.192180   0.611535
# 3  0.303271  0.740741  0.819514  ...  0.140900   0.312481   0.746326
# 4  0.380923  0.740741  0.681316  ...  0.150069   0.101955   0.699923
#
#    sensor_13  sensor_14  sensor_15  sensor_17  sensor_20  sensor_21  RUL
# 0   0.123529   0.162190   0.348561   0.210762   0.639065   0.681898  125
# 1   0.167647   0.192973   0.393804   0.300448   0.670761   0.693808  125
# 2   0.152941   0.189559   0.374250   0.479821   0.773772   0.715437  125
# 3   0.123529   0.213624   0.328624   0.300448   0.559826   0.797024  125
# 4   0.241176   0.186585   0.162989   0.300448   0.773772   0.674506  125
#
# [5 rows x 21 columns]
#
# Scaler saved to:
# ../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_scaler(removed_the_sensor).pkl
#
# Training dataset saved to:
# ../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_training_scaled(removed_the_sensor).csv
#
# Validation dataset saved to:
# ../CMAPSSData/Processed/train_FD001_cleaned_added_RUL_validation_scaled(removed_the_sensor).csv
