# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
RANDOM_SEED = 42

# Setting random seeds for reproducibility
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

WINDOW_SIZE_EXPECTED = 30
NUMBER_OF_FEATURES_EXPECTED = 18  # constant sensors removed (26 - 6)

# %%
X_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "X_train_sequences(removed_the_sensor).npy"
)

Y_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "y_train_sequences(removed_the_sensor).npy"
)

X_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "X_val_sequences(removed_the_sensor).npy"
)

Y_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "y_val_sequences(removed_the_sensor).npy"
)

# %%
BEST_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_best.keras"
)

FINAL_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_final.keras"
)

HISTORY_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_history.npz"
)

# %%
X_train = np.load(X_TRAIN_PATH)
y_train = np.load(Y_TRAIN_PATH)

X_val = np.load(X_VAL_PATH)
y_val = np.load(Y_VAL_PATH)


print("\nTraining data:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

print("\nValidation data:")
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# Training data:
# X_train shape: (13818, 30, 18)
# y_train shape: (13818,)
#
# Validation data:
# X_val shape: (3913, 30, 18)
# y_val shape: (3913,)

# %%
print("\nX_train dtype:", X_train.dtype)
print("y_train dtype:", y_train.dtype)

print("\nX_train minimum:", X_train.min())
print("X_train maximum:", X_train.max())

print("\ny_train minimum:", y_train.min())
print("y_train maximum:", y_train.max())

assert y_train.max() <= 125, (
    "y_train max exceeds 125 -- RUL capping was not applied "
    "upstream. Re-run calculate_rul.ipynb through create_sequence.py."
)
# Out:
# X_train dtype: float32
# y_train dtype: float32
#
# X_train minimum: 0.0
# X_train maximum: 1.0
#
# y_train minimum: 0.0
# y_train maximum: 125.0

# %%
print("DATA VALIDATION")

if X_train.ndim != 3:
    raise ValueError(
        f"X_train must be 3-dimensional. "
        f"Found shape: {X_train.shape}"
    )

if X_val.ndim != 3:
    raise ValueError(
        f"X_val must be 3-dimensional. "
        f"Found shape: {X_val.shape}"
    )

window_size = X_train.shape[1]

if window_size != WINDOW_SIZE_EXPECTED:
    print(
        f"\nWARNING: Expected window size "
        f"{WINDOW_SIZE_EXPECTED}, "
        f"but found {window_size}."
    )

number_of_features = X_train.shape[2]

if number_of_features != NUMBER_OF_FEATURES_EXPECTED:
    print(
        f"\nWARNING: Expected {NUMBER_OF_FEATURES_EXPECTED} features "
        f"(constant sensors removed), but found {number_of_features}. "
        f"Check you loaded the (removed_the_sensor) files."
    )

if X_val.shape[2] != number_of_features:
    raise ValueError(
        "Training and validation datasets have "
        "different numbers of features."
    )

if len(X_train) != len(y_train):
    raise ValueError(
        "X_train and y_train have different "
        "numbers of samples."
    )

if len(X_val) != len(y_val):
    raise ValueError(
        "X_val and y_val have different "
        "numbers of samples."
    )

print("\nNaN values:")

print("X_train:", np.isnan(X_train).sum())
print("y_train:", np.isnan(y_train).sum())
print("X_val:", np.isnan(X_val).sum())
print("y_val:", np.isnan(y_val).sum())


print("\nInfinite values:")

print("X_train:", np.isinf(X_train).sum())
print("y_train:", np.isinf(y_train).sum())
print("X_val:", np.isinf(X_val).sum())
print("y_val:", np.isinf(y_val).sum())


if (
    np.isnan(X_train).any()
    or np.isnan(y_train).any()
    or np.isnan(X_val).any()
    or np.isnan(y_val).any()
):
    raise ValueError("NaN values detected in the dataset.")

if (
    np.isinf(X_train).any()
    or np.isinf(y_train).any()
    or np.isinf(X_val).any()
    or np.isinf(y_val).any()
):
    raise ValueError(
        "Infinite values detected in the dataset."
    )
# Out:
# DATA VALIDATION
#
# NaN values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0
#
# Infinite values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0

# %%
print("INPUT INFORMATION")

print("\nWindow size:", window_size)
print("Number of features:", number_of_features)
print(
    "Input shape:",
    X_train.shape[1:]
)

print("\nTraining samples:", len(X_train))
print("Validation samples:", len(X_val))


print("\nTraining RUL range:")
print("Minimum:", y_train.min())
print("Maximum:", y_train.max())

print("\nValidation RUL range:")
print("Minimum:", y_val.min())
print("Maximum:", y_val.max())
# Out:
# INPUT INFORMATION
#
# Window size: 30
# Number of features: 18
# Input shape: (30, 18)
#
# Training samples: 13818
# Validation samples: 3913
#
# Training RUL range:
# Minimum: 0.0
# Maximum: 125.0
#
# Validation RUL range:
# Minimum: 0.0
# Maximum: 125.0

# %%
print("Building LSTM Model")

INPUT_SHAPE = X_train.shape[1:]

model = Sequential([
    Input(shape=INPUT_SHAPE),

    Bidirectional(
        LSTM(128, return_sequences=True)
    ),
    Dropout(0.2),
    Bidirectional(
        LSTM(64, return_sequences=True)
    ),
    Dropout(0.2),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(16, activation="relu"),
    Dense(1)
])
# Out:
# Building LSTM Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print("LSTM Model Architecture")
model.summary()
# Out:
# LSTM Model Architecture
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 30, 256)        │       150,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 30, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 336,033 (1.28 MB)
#  Trainable params: 336,033 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("SETTING TRAINING CALLBACKS")

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    mode='min',
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    mode='min',
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH,
    monitor="val_loss",
    mode="min",
    save_best_only=True,
    verbose=1
)
# Out:
# SETTING TRAINING CALLBACKS

# %%
print("STARTING LSTM TRAINING")

history = model.fit(
    X_train, y_train,
    validation_data=(
        X_val,
        y_val
    ),
    epochs=100,
    batch_size=64,
    callbacks=[
        early_stopping,
        reduce_lr,
        model_checkpoint
    ],
    verbose=1
)
# Out:
# STARTING LSTM TRAINING
# Epoch 1/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4765.0464 - mae: 58.4145
# Epoch 1: val_loss improved from None to 2760.64893, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 1: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 15s 46ms/step - loss: 4756.9458 - mae: 58.3721 - val_loss: 2760.6489 - val_mae: 46.4173 - learning_rate: 0.0010
# Epoch 2/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1925.9136 - mae: 38.8366
# Epoch 2: val_loss improved from 2760.64893 to 1796.67957, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 2: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1927.2300 - mae: 38.8498 - val_loss: 1796.6796 - val_mae: 38.2884 - learning_rate: 0.0010
# Epoch 3/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1778.6858 - mae: 37.2567
# Epoch 3: val_loss improved from 1796.67957 to 1784.13464, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 3: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1779.9382 - mae: 37.2712 - val_loss: 1784.1346 - val_mae: 38.0963 - learning_rate: 0.0010
# Epoch 4/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1791.2872 - mae: 37.3520
# Epoch 4: val_loss improved from 1784.13464 to 1783.64087, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 4: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 1792.6888 - mae: 37.3668 - val_loss: 1783.6409 - val_mae: 38.0884 - learning_rate: 0.0010
# Epoch 5/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1785.6306 - mae: 37.3361
# Epoch 5: val_loss improved from 1783.64087 to 1782.51099, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 5: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1786.7219 - mae: 37.3490 - val_loss: 1782.5110 - val_mae: 38.0703 - learning_rate: 0.0010
# Epoch 6/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1784.6678 - mae: 37.2974
# Epoch 6: val_loss did not improve from 1782.51099
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 1786.5216 - mae: 37.3188 - val_loss: 1783.7469 - val_mae: 38.0901 - learning_rate: 0.0010
# Epoch 7/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1778.0901 - mae: 37.2636
# Epoch 7: val_loss improved from 1782.51099 to 1782.35339, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 7: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1779.7903 - mae: 37.2813 - val_loss: 1782.3534 - val_mae: 38.0678 - learning_rate: 0.0010
# Epoch 8/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1786.8398 - mae: 37.3488
# Epoch 8: val_loss did not improve from 1782.35339
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 1788.1896 - mae: 37.3616 - val_loss: 1783.2538 - val_mae: 38.0823 - learning_rate: 0.0010
# Epoch 9/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1782.3640 - mae: 37.3254
# Epoch 9: val_loss improved from 1782.35339 to 1782.09924, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 9: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1784.1736 - mae: 37.3428 - val_loss: 1782.0992 - val_mae: 38.0643 - learning_rate: 0.0010
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1188.4160 - mae: 28.9303
# Epoch 10: val_loss improved from 1782.09924 to 500.17026, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 10: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 1188.4160 - mae: 28.9303 - val_loss: 500.1703 - val_mae: 18.6724 - learning_rate: 0.0010
# Epoch 11/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 399.7662 - mae: 15.6367
# Epoch 11: val_loss improved from 500.17026 to 325.44995, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 11: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 398.8127 - mae: 15.6169 - val_loss: 325.4500 - val_mae: 14.1116 - learning_rate: 0.0010
# Epoch 12/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 334.8326 - mae: 14.2269
# Epoch 12: val_loss did not improve from 325.44995
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 334.2705 - mae: 14.2114 - val_loss: 337.7388 - val_mae: 13.5351 - learning_rate: 0.0010
# Epoch 13/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 303.4407 - mae: 13.4277
# Epoch 13: val_loss improved from 325.44995 to 287.78647, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 13: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 302.9811 - mae: 13.4164 - val_loss: 287.7865 - val_mae: 12.3904 - learning_rate: 0.0010
# Epoch 14/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 279.2733 - mae: 12.8454
# Epoch 14: val_loss improved from 287.78647 to 249.72166, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 14: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - loss: 278.8416 - mae: 12.8355 - val_loss: 249.7217 - val_mae: 11.6283 - learning_rate: 0.0010
# Epoch 15/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 251.0161 - mae: 12.0875
# Epoch 15: val_loss improved from 249.72166 to 222.61992, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 15: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 251.0161 - mae: 12.0875 - val_loss: 222.6199 - val_mae: 10.9232 - learning_rate: 0.0010
# Epoch 16/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 234.4955 - mae: 11.6402
# Epoch 16: val_loss improved from 222.61992 to 193.46384, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 16: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 234.2150 - mae: 11.6322 - val_loss: 193.4638 - val_mae: 10.0981 - learning_rate: 0.0010
# Epoch 17/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 226.8578 - mae: 11.4388
# Epoch 17: val_loss did not improve from 193.46384
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 226.5500 - mae: 11.4289 - val_loss: 223.1009 - val_mae: 10.5632 - learning_rate: 0.0010
# Epoch 18/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 224.8878 - mae: 11.3755
# Epoch 18: val_loss did not improve from 193.46384
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 224.8194 - mae: 11.3747 - val_loss: 214.9412 - val_mae: 10.6744 - learning_rate: 0.0010
# Epoch 19/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 216.3448 - mae: 11.1643
# Epoch 19: val_loss did not improve from 193.46384
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 216.0662 - mae: 11.1569 - val_loss: 206.6648 - val_mae: 10.1332 - learning_rate: 0.0010
# Epoch 20/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 210.5141 - mae: 10.9975
# Epoch 20: val_loss did not improve from 193.46384
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 210.3993 - mae: 10.9932 - val_loss: 226.5730 - val_mae: 10.4782 - learning_rate: 0.0010
# Epoch 21/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 202.9871 - mae: 10.8281
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_loss did not improve from 193.46384
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 202.8492 - mae: 10.8235 - val_loss: 270.9244 - val_mae: 11.1998 - learning_rate: 0.0010
# Epoch 22/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 190.7489 - mae: 10.4029
# Epoch 22: val_loss improved from 193.46384 to 190.15456, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 22: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 190.5736 - mae: 10.3977 - val_loss: 190.1546 - val_mae: 9.7389 - learning_rate: 5.0000e-04
# Epoch 23/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 184.4502 - mae: 10.2666
# Epoch 23: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 184.2110 - mae: 10.2598 - val_loss: 223.0535 - val_mae: 10.4705 - learning_rate: 5.0000e-04
# Epoch 24/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 173.9627 - mae: 9.9486
# Epoch 24: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 174.0064 - mae: 9.9501 - val_loss: 200.0619 - val_mae: 10.0655 - learning_rate: 5.0000e-04
# Epoch 25/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 177.6918 - mae: 10.0028
# Epoch 25: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - loss: 177.3845 - mae: 9.9949 - val_loss: 203.8967 - val_mae: 10.0322 - learning_rate: 5.0000e-04
# Epoch 26/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 170.7108 - mae: 9.8565
# Epoch 26: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - loss: 170.4942 - mae: 9.8501 - val_loss: 209.7600 - val_mae: 10.2781 - learning_rate: 5.0000e-04
# Epoch 27/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 166.6543 - mae: 9.7102
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 27: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 166.5017 - mae: 9.7057 - val_loss: 212.5625 - val_mae: 10.3496 - learning_rate: 5.0000e-04
# Epoch 28/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 161.0699 - mae: 9.5777
# Epoch 28: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 160.9521 - mae: 9.5751 - val_loss: 198.5689 - val_mae: 10.0738 - learning_rate: 2.5000e-04
# Epoch 29/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 156.9331 - mae: 9.3767
# Epoch 29: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 156.8436 - mae: 9.3756 - val_loss: 204.2596 - val_mae: 10.1500 - learning_rate: 2.5000e-04
# Epoch 30/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 151.9742 - mae: 9.2701
# Epoch 30: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 151.8577 - mae: 9.2663 - val_loss: 210.3895 - val_mae: 10.2603 - learning_rate: 2.5000e-04
# Epoch 31/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 149.2109 - mae: 9.2032
# Epoch 31: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 148.9993 - mae: 9.1981 - val_loss: 203.1456 - val_mae: 10.0007 - learning_rate: 2.5000e-04
# Epoch 32/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 149.1866 - mae: 9.2262
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 32: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 148.9858 - mae: 9.2204 - val_loss: 210.7032 - val_mae: 10.4037 - learning_rate: 2.5000e-04
# Epoch 33/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 142.2451 - mae: 9.0369
# Epoch 33: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 142.0285 - mae: 9.0288 - val_loss: 215.7417 - val_mae: 10.4777 - learning_rate: 1.2500e-04
# Epoch 34/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 139.6799 - mae: 8.9173
# Epoch 34: val_loss did not improve from 190.15456
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - loss: 139.5722 - mae: 8.9153 - val_loss: 207.5787 - val_mae: 10.2993 - learning_rate: 1.2500e-04
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
model.save(FINAL_MODEL_PATH)

print("MODEL TRAINING COMPLETED")

print("\nFinal model saved at:")
print(FINAL_MODEL_PATH)

print("\nBest model saved at:")
print(BEST_MODEL_PATH)
# Out:
# MODEL TRAINING COMPLETED
#
# Final model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_final.keras
#
# Best model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras

# %%
np.savez(
    HISTORY_PATH,

    loss=np.array(
        history.history["loss"]
    ),

    val_loss=np.array(
        history.history["val_loss"]
    ),

    mae=np.array(
        history.history["mae"]
    ),

    val_mae=np.array(
        history.history["val_mae"]
    )
)

# %%
print("TRAINING INFORMATION")

print("Total epochs requested", 100)
print("Actual epochs completed:", len(history.history['loss']))
print("Best validation loss:", min(history.history["val_loss"]))
print("Best validation MAE:", min(history.history["val_mae"]))

# Overfitting check: compare final train vs val MAE directly
final_train_mae = history.history['mae'][-1]
final_val_mae = history.history['val_mae'][-1]
gap = final_val_mae - final_train_mae
print(f"\nFinal train MAE: {final_train_mae:.3f}")
print(f"Final val MAE:   {final_val_mae:.3f}")
print(f"Train/val gap:   {gap:.3f} cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)")
# Out:
# TRAINING INFORMATION
# Total epochs requested 100
# Actual epochs completed: 34
# Best validation loss: 190.15455627441406
# Best validation MAE: 9.738922119140625
#
# Final train MAE: 8.915
# Final val MAE:   10.299
# Train/val gap:   1.384 cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["loss"], label="Training Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training vs Validation Loss")

plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["mae"], label="Training MAE")

plt.plot(history.history["val_mae"], label="Validation MAE")

plt.xlabel("Epoch")
plt.ylabel("MAE (Cycles)")
plt.title("Training vs Validation MAE")

plt.legend()
plt.grid(True)

plt.tight_layout()

plt.show()

# %%
print("VALIDATION PREDICTION")

y_pred = model.predict(
    X_val,
    verbose=1
)

y_pred = y_pred.reshape(-1)

mae = mean_absolute_error(y_val, y_pred)

mse = mean_squared_error(y_val, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_val, y_pred)
# Out:
# VALIDATION PREDICTION
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step

# %%
print("VALIDATION PERFORMANCE")

print(f"\nMAE : {mae:.4f} cycles")

print(f"RMSE  : {rmse:.4f} cycles")

print(f"R²    : {r2:.4f}")
# Out:
# VALIDATION PERFORMANCE
#
# MAE : 9.7389 cycles
# RMSE  : 13.7897 cycles
# R²    : 0.8914

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_val, y_pred, alpha=0.5)

# Perfect prediction line

minimum = min(y_val.min(), y_pred.min())

maximum = max(y_val.max(), y_pred.max())

plt.plot([minimum, maximum], [minimum, maximum], linestyle="--")

plt.xlabel("Actual RUL")
plt.ylabel("Predicted RUL")

plt.title("Actual RUL vs Predicted RUL")

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
number_to_plot = min(300, len(y_val))

plt.figure(figsize=(12, 6))

plt.plot(y_val[:number_to_plot], label="Actual RUL")

plt.plot(y_pred[:number_to_plot], label="Predicted RUL")

plt.xlabel("Validation Sample")
plt.ylabel("RUL (Cycles)")

plt.title("Actual vs Predicted RUL on Validation Data")

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("FINAL SUMMARY")
print(f"Validation MAE  : {mae:.4f} cycles")
print(f"Validation RMSE : {rmse:.4f} cycles")
print(f"Validation R²   : {r2:.4f}")
print("\nTraining completed successfully.")
# Out:
# FINAL SUMMARY
# Validation MAE  : 9.7389 cycles
# Validation RMSE : 13.7897 cycles
# Validation R²   : 0.8914
#
# Training completed successfully.
