# %% [markdown]
# # LSTM for CMAPSS FD001 RUL Prediction (corrected)
#
# ## What changed from `04_LSTM_with_all_sensor.ipynb`, and why
#
# Your last run: **R² = 0.636–0.67, train MAE ~20–21 vs val MAE fluctuating
# 32–38** — a real, widening train/val gap (genuine overfitting), plus a val
# loss that bounces around a lot epoch to epoch (2957 → 2058 → 2952 → 3022 →
# 2209...). Two separate problems were stacked together, so here's what's
# fixed and why, in priority order:
#
# 1. **Switched input data to the constant-sensor-removed + RUL-capped
#    sequences** (18 features instead of 24, RUL capped at 125 instead of
#    raw up to 332). This is a data-level fix, not architecture — it removes
#    unlearnable target variance and pure-noise input columns. Expect this
#    alone to move R² up meaningfully regardless of what the model looks
#    like.
# 2. **Removed `BatchNormalization` from inside the recurrent stack.**
#    BatchNorm normalizes over the *batch* dimension at every timestep, and
#    its running statistics frequently don't transfer well between training
#    and inference in a stacked RNN — this is a known instability source,
#    and it lines up with the noisy epoch-to-epoch val_loss you saw
#    (2957→2058→2952→3022 is not just healthy noise, it's a sign the
#    normalization statistics aren't settling). Swapped for nothing —
#    `LayerNormalization` is the safer alternative when normalization is
#    needed inside a recurrent stack, but the added capacity here doesn't
#    need it once the target/inputs are cleaned up.
# 3. **Reduced from two stacked `Bidirectional` layers (344K params) to
#    one.** The previous model doubled parameters twice on top of an
#    already-small dataset (13.8K training sequences) — that's a lot of
#    capacity relative to the data, which is exactly the setup that
#    overfits. One Bidirectional layer is still a legitimate capacity
#    increase (you have the full window at inference time, so there's no
#    reason to withhold the backward pass), just not stacked twice.
# 4. **Kept dropout modest (0.2) and did NOT add L2 on top of it.** Per the
#    "don't stack regularizers defensively" rule — add L2 only if this run
#    *still* shows a clear overfitting gap; adding it preemptively risks
#    pushing back into underfitting the way BatchNorm+L2+Bidirectional all
#    at once did last time.
#
# **Test this as one change-set against your baseline**, then if you want to
# push further, adjust ONE thing at a time from here (e.g. try adding
# LayerNormalization back in, or a second Bidirectional layer) so you can
# tell what actually moved the number.
#
# ## Realistic expectation
#
# Published FD001 benchmarks (capped RUL, RMSE-based) sit around RMSE 11-14,
# which is roughly R² 0.85-0.92. That's the realistic ceiling to aim for —
# not 0.96-0.98, which on this dataset usually signals a leakage or
# target-mismatch bug rather than a genuinely better model.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
RANDOM_SEED = 42

# Setting random seeds for reproducibility
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

WINDOW_SIZE_EXPECTED = 30
NUMBER_OF_FEATURES_EXPECTED = 18  # constant sensors removed (26 - 6)

# %% [markdown]
# ## Data paths (CHANGED)
#
# Switched from `(not_removed_the_sensor)` to `(removed_the_sensor)` — these
# sequences also now carry the capped RUL target once you've re-run
# `calculate_rul.ipynb` → `spliting_data.ipynb` → `03_Feature_Scaling.ipynb`
# → `create_sequence.py` in that order.

# %%
X_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "X_train_sequences(removed_the_sensor).npy"
)

Y_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "y_train_sequences(removed_the_sensor).npy"
)

X_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "X_val_sequences(removed_the_sensor).npy"
)

Y_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "y_val_sequences(removed_the_sensor).npy"
)

# %%
BEST_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_best.keras"
)

FINAL_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_final.keras"
)

HISTORY_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_history.npz"
)

# %%
X_train = np.load(X_TRAIN_PATH)
y_train = np.load(Y_TRAIN_PATH)

X_val = np.load(X_VAL_PATH)
y_val = np.load(Y_VAL_PATH)


print("\nTraining data:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

print("\nValidation data:")
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# Training data:
# X_train shape: (13818, 30, 18)
# y_train shape: (13818,)
#
# Validation data:
# X_val shape: (3913, 30, 18)
# y_val shape: (3913,)

# %%
print("\nX_train dtype:", X_train.dtype)
print("y_train dtype:", y_train.dtype)

print("\nX_train minimum:", X_train.min())
print("X_train maximum:", X_train.max())

print("\ny_train minimum:", y_train.min())
print("y_train maximum:", y_train.max())

assert y_train.max() <= 125, (
    "y_train max exceeds 125 -- RUL capping was not applied "
    "upstream. Re-run calculate_rul.ipynb through create_sequence.py."
)
# Out:
# X_train dtype: float32
# y_train dtype: float32
#
# X_train minimum: 0.0
# X_train maximum: 1.0
#
# y_train minimum: 0.0
# y_train maximum: 125.0

# %%
print("DATA VALIDATION")

if X_train.ndim != 3:
    raise ValueError(
        f"X_train must be 3-dimensional. "
        f"Found shape: {X_train.shape}"
    )

if X_val.ndim != 3:
    raise ValueError(
        f"X_val must be 3-dimensional. "
        f"Found shape: {X_val.shape}"
    )

window_size = X_train.shape[1]

if window_size != WINDOW_SIZE_EXPECTED:
    print(
        f"\nWARNING: Expected window size "
        f"{WINDOW_SIZE_EXPECTED}, "
        f"but found {window_size}."
    )

number_of_features = X_train.shape[2]

if number_of_features != NUMBER_OF_FEATURES_EXPECTED:
    print(
        f"\nWARNING: Expected {NUMBER_OF_FEATURES_EXPECTED} features "
        f"(constant sensors removed), but found {number_of_features}. "
        f"Check you loaded the (removed_the_sensor) files."
    )

if X_val.shape[2] != number_of_features:
    raise ValueError(
        "Training and validation datasets have "
        "different numbers of features."
    )

if len(X_train) != len(y_train):
    raise ValueError(
        "X_train and y_train have different "
        "numbers of samples."
    )

if len(X_val) != len(y_val):
    raise ValueError(
        "X_val and y_val have different "
        "numbers of samples."
    )

print("\nNaN values:")

print("X_train:", np.isnan(X_train).sum())
print("y_train:", np.isnan(y_train).sum())
print("X_val:", np.isnan(X_val).sum())
print("y_val:", np.isnan(y_val).sum())


print("\nInfinite values:")

print("X_train:", np.isinf(X_train).sum())
print("y_train:", np.isinf(y_train).sum())
print("X_val:", np.isinf(X_val).sum())
print("y_val:", np.isinf(y_val).sum())


if (
    np.isnan(X_train).any()
    or np.isnan(y_train).any()
    or np.isnan(X_val).any()
    or np.isnan(y_val).any()
):
    raise ValueError("NaN values detected in the dataset.")

if (
    np.isinf(X_train).any()
    or np.isinf(y_train).any()
    or np.isinf(X_val).any()
    or np.isinf(y_val).any()
):
    raise ValueError(
        "Infinite values detected in the dataset."
    )
# Out:
# DATA VALIDATION
#
# NaN values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0
#
# Infinite values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0

# %%
print("INPUT INFORMATION")

print("\nWindow size:", window_size)
print("Number of features:", number_of_features)
print(
    "Input shape:",
    X_train.shape[1:]
)

print("\nTraining samples:", len(X_train))
print("Validation samples:", len(X_val))


print("\nTraining RUL range:")
print("Minimum:", y_train.min())
print("Maximum:", y_train.max())

print("\nValidation RUL range:")
print("Minimum:", y_val.min())
print("Maximum:", y_val.max())
# Out:
# INPUT INFORMATION
#
# Window size: 30
# Number of features: 18
# Input shape: (30, 18)
#
# Training samples: 13818
# Validation samples: 3913
#
# Training RUL range:
# Minimum: 0.0
# Maximum: 125.0
#
# Validation RUL range:
# Minimum: 0.0
# Maximum: 125.0

# %% [markdown]
# ## Model architecture (CHANGED)
#
# Single `Bidirectional(LSTM(64))` (not two stacked), no `BatchNormalization`,
# moderate `Dropout(0.2)` between layers, no L2. ~half the parameter count of
# the previous 344K-param version, sized more sensibly for 13.8K training
# sequences.

# %%
print("Building LSTM Model")

INPUT_SHAPE = X_train.shape[1:]

model = Sequential([
    Input(shape=INPUT_SHAPE),

    # Bidirectional(
    #     LSTM(256, return_sequences=True)
    # ),
    # Dropout(0.2),

    Bidirectional(
        LSTM(128, return_sequences=True)
    ),
    Dropout(0.2),
    Bidirectional(
        LSTM(64, return_sequences=True)
    ),
    Dropout(0.2),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(16, activation="relu"),
    Dense(1)
])
# Out:
# Building LSTM Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
print("LSTM Model Architecture")
model.summary()
# Out:
# LSTM Model Architecture
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_6 (Bidirectional) │ (None, 30, 256)        │       150,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 30, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ (None, 30, 128)        │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 336,033 (1.28 MB)
#  Trainable params: 336,033 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("SETTING TRAINING CALLBACKS")

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    mode='min',
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    mode='min',
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH,
    monitor="val_loss",
    mode="min",
    save_best_only=True,
    verbose=1
)
# Out:
# SETTING TRAINING CALLBACKS

# %%
print("STARTING LSTM TRAINING")

history = model.fit(
    X_train, y_train,
    validation_data=(
        X_val,
        y_val
    ),
    epochs=100,
    batch_size=64,
    callbacks=[
        early_stopping,
        reduce_lr,
        model_checkpoint
    ],
    verbose=1
)
# Out:
# STARTING LSTM TRAINING
# Epoch 1/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 6153.5195 - mae: 67.4151
# Epoch 1: val_loss improved from None to 4728.20410, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 1: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 17s 51ms/step - loss: 6146.7734 - mae: 67.3777 - val_loss: 4728.2041 - val_mae: 59.3927 - learning_rate: 0.0010
# Epoch 2/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2738.3169 - mae: 44.9835
# Epoch 2: val_loss improved from 4728.20410 to 2021.81091, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 2: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 2735.9343 - mae: 44.9710 - val_loss: 2021.8109 - val_mae: 40.6808 - learning_rate: 0.0010
# Epoch 3/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1803.0442 - mae: 37.6563
# Epoch 3: val_loss improved from 2021.81091 to 1786.56995, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 3: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - loss: 1803.0442 - mae: 37.6563 - val_loss: 1786.5699 - val_mae: 38.1359 - learning_rate: 0.0010
# Epoch 4/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1785.1477 - mae: 37.2898
# Epoch 4: val_loss improved from 1786.56995 to 1784.51282, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 4: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 1786.9525 - mae: 37.3082 - val_loss: 1784.5128 - val_mae: 38.1023 - learning_rate: 0.0010
# Epoch 5/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1781.6011 - mae: 37.2922
# Epoch 5: val_loss did not improve from 1784.51282
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 1783.0403 - mae: 37.3074 - val_loss: 1786.3251 - val_mae: 38.1319 - learning_rate: 0.0010
# Epoch 6/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1785.4652 - mae: 37.3585
# Epoch 6: val_loss did not improve from 1784.51282
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 1786.4529 - mae: 37.3701 - val_loss: 1785.0347 - val_mae: 38.1109 - learning_rate: 0.0010
# Epoch 7/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1788.9819 - mae: 37.3793
# Epoch 7: val_loss improved from 1784.51282 to 1784.27026, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 7: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 1790.3906 - mae: 37.3926 - val_loss: 1784.2703 - val_mae: 38.0984 - learning_rate: 0.0010
# Epoch 8/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1785.5786 - mae: 37.3612
# Epoch 8: val_loss did not improve from 1784.27026
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 1787.2782 - mae: 37.3773 - val_loss: 1785.1921 - val_mae: 38.1135 - learning_rate: 0.0010
# Epoch 9/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1799.1576 - mae: 37.4728
# Epoch 9: val_loss did not improve from 1784.27026
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 1800.8783 - mae: 37.4907 - val_loss: 1784.6552 - val_mae: 38.1047 - learning_rate: 0.0010
# Epoch 10/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1787.8459 - mae: 37.3943
# Epoch 10: val_loss improved from 1784.27026 to 1783.89636, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 10: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 1787.8459 - mae: 37.3943 - val_loss: 1783.8964 - val_mae: 38.0925 - learning_rate: 0.0010
# Epoch 11/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1781.4253 - mae: 37.2785
# Epoch 11: val_loss did not improve from 1783.89636
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 1783.0342 - mae: 37.2932 - val_loss: 1783.9999 - val_mae: 38.0941 - learning_rate: 0.0010
# Epoch 12/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1797.0001 - mae: 37.4703
# Epoch 12: val_loss did not improve from 1783.89636
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 1798.7688 - mae: 37.4891 - val_loss: 1786.3966 - val_mae: 38.1331 - learning_rate: 0.0010
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1789.6077 - mae: 37.3900
# Epoch 13: val_loss did not improve from 1783.89636
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 1789.6077 - mae: 37.3900 - val_loss: 1784.3613 - val_mae: 38.0998 - learning_rate: 0.0010
# Epoch 14/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1780.7874 - mae: 37.2491
# Epoch 14: val_loss improved from 1783.89636 to 1782.25732, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 14: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 1780.7874 - mae: 37.2491 - val_loss: 1782.2573 - val_mae: 38.0662 - learning_rate: 0.0010
# Epoch 15/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1779.1481 - mae: 37.2750
# Epoch 15: val_loss improved from 1782.25732 to 1781.80237, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 15: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 1780.7310 - mae: 37.2922 - val_loss: 1781.8024 - val_mae: 38.0589 - learning_rate: 0.0010
# Epoch 16/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1182.2946 - mae: 28.6704
# Epoch 16: val_loss improved from 1781.80237 to 509.44302, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 16: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 1182.2946 - mae: 28.6704 - val_loss: 509.4430 - val_mae: 18.7432 - learning_rate: 0.0010
# Epoch 17/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 501.7432 - mae: 17.6668
# Epoch 17: val_loss improved from 509.44302 to 425.37662, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 17: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 501.7432 - mae: 17.6668 - val_loss: 425.3766 - val_mae: 16.7457 - learning_rate: 0.0010
# Epoch 18/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 452.1054 - mae: 16.5330
# Epoch 18: val_loss did not improve from 425.37662
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 451.5981 - mae: 16.5206 - val_loss: 436.9507 - val_mae: 16.7804 - learning_rate: 0.0010
# Epoch 19/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 520.4600 - mae: 17.8885
# Epoch 19: val_loss did not improve from 425.37662
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 519.6412 - mae: 17.8682 - val_loss: 426.5434 - val_mae: 16.9093 - learning_rate: 0.0010
# Epoch 20/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 452.1653 - mae: 16.3613
# Epoch 20: val_loss improved from 425.37662 to 345.24332, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 20: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 451.3782 - mae: 16.3465 - val_loss: 345.2433 - val_mae: 14.0907 - learning_rate: 0.0010
# Epoch 21/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 324.6447 - mae: 13.5961
# Epoch 21: val_loss improved from 345.24332 to 229.35754, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 21: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 324.1750 - mae: 13.5835 - val_loss: 229.3575 - val_mae: 11.9027 - learning_rate: 0.0010
# Epoch 22/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 269.1750 - mae: 12.3071
# Epoch 22: val_loss improved from 229.35754 to 227.18216, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 22: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - loss: 269.1750 - mae: 12.3071 - val_loss: 227.1822 - val_mae: 11.6776 - learning_rate: 0.0010
# Epoch 23/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 251.6904 - mae: 11.8332
# Epoch 23: val_loss did not improve from 227.18216
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 251.5233 - mae: 11.8267 - val_loss: 228.4371 - val_mae: 11.5313 - learning_rate: 0.0010
# Epoch 24/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 242.3513 - mae: 11.5384
# Epoch 24: val_loss improved from 227.18216 to 196.95764, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 24: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 242.1189 - mae: 11.5348 - val_loss: 196.9576 - val_mae: 10.4783 - learning_rate: 0.0010
# Epoch 25/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 235.1509 - mae: 11.3784
# Epoch 25: val_loss did not improve from 196.95764
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 235.1509 - mae: 11.3784 - val_loss: 211.0663 - val_mae: 10.7931 - learning_rate: 0.0010
# Epoch 26/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 225.5405 - mae: 11.1059
# Epoch 26: val_loss did not improve from 196.95764
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 225.2919 - mae: 11.1011 - val_loss: 208.1469 - val_mae: 10.7376 - learning_rate: 0.0010
# Epoch 27/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 224.8817 - mae: 11.1256
# Epoch 27: val_loss did not improve from 196.95764
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 224.8817 - mae: 11.1256 - val_loss: 204.9881 - val_mae: 10.3040 - learning_rate: 0.0010
# Epoch 28/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 227.5131 - mae: 11.1009
# Epoch 28: val_loss did not improve from 196.95764
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 227.5131 - mae: 11.1009 - val_loss: 201.8070 - val_mae: 10.4740 - learning_rate: 0.0010
# Epoch 29/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 223.4965 - mae: 11.0318
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 29: val_loss did not improve from 196.95764
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 223.1359 - mae: 11.0235 - val_loss: 219.5257 - val_mae: 11.0331 - learning_rate: 0.0010
# Epoch 30/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 213.5872 - mae: 10.7699
# Epoch 30: val_loss improved from 196.95764 to 167.69128, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 30: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 213.4618 - mae: 10.7643 - val_loss: 167.6913 - val_mae: 9.4989 - learning_rate: 5.0000e-04
# Epoch 31/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 210.6008 - mae: 10.6133
# Epoch 31: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - loss: 210.3859 - mae: 10.6059 - val_loss: 193.2435 - val_mae: 10.3279 - learning_rate: 5.0000e-04
# Epoch 32/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 205.7873 - mae: 10.4842
# Epoch 32: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 205.4460 - mae: 10.4765 - val_loss: 170.7675 - val_mae: 9.6123 - learning_rate: 5.0000e-04
# Epoch 33/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 206.3715 - mae: 10.5187
# Epoch 33: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 206.1406 - mae: 10.5138 - val_loss: 230.9731 - val_mae: 11.2318 - learning_rate: 5.0000e-04
# Epoch 34/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 206.5596 - mae: 10.5518
# Epoch 34: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 206.5596 - mae: 10.5518 - val_loss: 176.8807 - val_mae: 9.7293 - learning_rate: 5.0000e-04
# Epoch 35/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 202.9141 - mae: 10.4274
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 35: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 202.6962 - mae: 10.4197 - val_loss: 181.7257 - val_mae: 9.9163 - learning_rate: 5.0000e-04
# Epoch 36/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 200.2795 - mae: 10.3642
# Epoch 36: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 200.0273 - mae: 10.3592 - val_loss: 180.7608 - val_mae: 9.9052 - learning_rate: 2.5000e-04
# Epoch 37/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 198.2314 - mae: 10.2997
# Epoch 37: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 58ms/step - loss: 197.9978 - mae: 10.2931 - val_loss: 183.0081 - val_mae: 9.9025 - learning_rate: 2.5000e-04
# Epoch 38/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 193.6711 - mae: 10.2222
# Epoch 38: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 193.4543 - mae: 10.2135 - val_loss: 178.4658 - val_mae: 9.7579 - learning_rate: 2.5000e-04
# Epoch 39/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 196.4665 - mae: 10.2483
# Epoch 39: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 196.0901 - mae: 10.2388 - val_loss: 180.3772 - val_mae: 9.9031 - learning_rate: 2.5000e-04
# Epoch 40/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 193.0230 - mae: 10.1637
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 40: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 192.7818 - mae: 10.1605 - val_loss: 171.6290 - val_mae: 9.6161 - learning_rate: 2.5000e-04
# Epoch 41/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 191.1091 - mae: 10.0960
# Epoch 41: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 57ms/step - loss: 190.8961 - mae: 10.0922 - val_loss: 176.1738 - val_mae: 9.7438 - learning_rate: 1.2500e-04
# Epoch 42/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 189.8763 - mae: 10.0461
# Epoch 42: val_loss did not improve from 167.69128
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 12s 58ms/step - loss: 189.7744 - mae: 10.0458 - val_loss: 181.5261 - val_mae: 9.8468 - learning_rate: 1.2500e-04
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 30.

# %%
model.save(FINAL_MODEL_PATH)

print("MODEL TRAINING COMPLETED")

print("\nFinal model saved at:")
print(FINAL_MODEL_PATH)

print("\nBest model saved at:")
print(BEST_MODEL_PATH)
# Out:
# MODEL TRAINING COMPLETED
#
# Final model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_final.keras
#
# Best model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras

# %%
np.savez(
    HISTORY_PATH,

    loss=np.array(
        history.history["loss"]
    ),

    val_loss=np.array(
        history.history["val_loss"]
    ),

    mae=np.array(
        history.history["mae"]
    ),

    val_mae=np.array(
        history.history["val_mae"]
    )
)

# %%
print("TRAINING INFORMATION")

print("Total epochs requested", 100)
print("Actual epochs completed:", len(history.history['loss']))
print("Best validation loss:", min(history.history["val_loss"]))
print("Best validation MAE:", min(history.history["val_mae"]))

# Overfitting check: compare final train vs val MAE directly
final_train_mae = history.history['mae'][-1]
final_val_mae = history.history['val_mae'][-1]
gap = final_val_mae - final_train_mae
print(f"\nFinal train MAE: {final_train_mae:.3f}")
print(f"Final val MAE:   {final_val_mae:.3f}")
print(f"Train/val gap:   {gap:.3f} cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)")
# Out:
# TRAINING INFORMATION
# Total epochs requested 100
# Actual epochs completed: 42
# Best validation loss: 167.6912841796875
# Best validation MAE: 9.498862266540527
#
# Final train MAE: 10.046
# Final val MAE:   9.847
# Train/val gap:   -0.199 cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["loss"], label="Training Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training vs Validation Loss")

plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["mae"], label="Training MAE")

plt.plot(history.history["val_mae"], label="Validation MAE")

plt.xlabel("Epoch")
plt.ylabel("MAE (Cycles)")
plt.title("Training vs Validation MAE")

plt.legend()
plt.grid(True)

plt.tight_layout()

plt.show()

# %%
print("VALIDATION PREDICTION")

y_pred = model.predict(
    X_val,
    verbose=1
)

y_pred = y_pred.reshape(-1)

mae = mean_absolute_error(y_val, y_pred)

mse = mean_squared_error(y_val, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_val, y_pred)
# Out:
# VALIDATION PREDICTION
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step

# %%
print("VALIDATION PERFORMANCE")

print(f"\nMAE : {mae:.4f} cycles")

print(f"RMSE  : {rmse:.4f} cycles")

print(f"R²    : {r2:.4f}")
# Out:
# VALIDATION PERFORMANCE
#
# MAE : 9.4989 cycles
# RMSE  : 12.9496 cycles
# R²    : 0.9042

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_val, y_pred, alpha=0.5)

# Perfect prediction line

minimum = min(y_val.min(), y_pred.min())

maximum = max(y_val.max(), y_pred.max())

plt.plot([minimum, maximum], [minimum, maximum], linestyle="--")

plt.xlabel("Actual RUL")
plt.ylabel("Predicted RUL")

plt.title("Actual RUL vs Predicted RUL")

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
number_to_plot = min(300, len(y_val))

plt.figure(figsize=(12, 6))

plt.plot(y_val[:number_to_plot], label="Actual RUL")

plt.plot(y_pred[:number_to_plot], label="Predicted RUL")

plt.xlabel("Validation Sample")
plt.ylabel("RUL (Cycles)")

plt.title("Actual vs Predicted RUL on Validation Data")

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("FINAL SUMMARY")
print(f"Validation MAE  : {mae:.4f} cycles")
print(f"Validation RMSE : {rmse:.4f} cycles")
print(f"Validation R²   : {r2:.4f}")
print("\nTraining completed successfully.")
# Out:
# FINAL SUMMARY
# Validation MAE  : 9.4989 cycles
# Validation RMSE : 12.9496 cycles
# Validation R²   : 0.9042
#
# Training completed successfully.
