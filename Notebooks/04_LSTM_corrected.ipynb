# %% [markdown]
# # LSTM for CMAPSS FD001 RUL Prediction (corrected)
#
# ## What changed from `04_LSTM_with_all_sensor.ipynb`, and why
#
# Your last run: **R² = 0.636–0.67, train MAE ~20–21 vs val MAE fluctuating
# 32–38** — a real, widening train/val gap (genuine overfitting), plus a val
# loss that bounces around a lot epoch to epoch (2957 → 2058 → 2952 → 3022 →
# 2209...). Two separate problems were stacked together, so here's what's
# fixed and why, in priority order:
#
# 1. **Switched input data to the constant-sensor-removed + RUL-capped
#    sequences** (18 features instead of 24, RUL capped at 125 instead of
#    raw up to 332). This is a data-level fix, not architecture — it removes
#    unlearnable target variance and pure-noise input columns. Expect this
#    alone to move R² up meaningfully regardless of what the model looks
#    like.
# 2. **Removed `BatchNormalization` from inside the recurrent stack.**
#    BatchNorm normalizes over the *batch* dimension at every timestep, and
#    its running statistics frequently don't transfer well between training
#    and inference in a stacked RNN — this is a known instability source,
#    and it lines up with the noisy epoch-to-epoch val_loss you saw
#    (2957→2058→2952→3022 is not just healthy noise, it's a sign the
#    normalization statistics aren't settling). Swapped for nothing —
#    `LayerNormalization` is the safer alternative when normalization is
#    needed inside a recurrent stack, but the added capacity here doesn't
#    need it once the target/inputs are cleaned up.
# 3. **Reduced from two stacked `Bidirectional` layers (344K params) to
#    one.** The previous model doubled parameters twice on top of an
#    already-small dataset (13.8K training sequences) — that's a lot of
#    capacity relative to the data, which is exactly the setup that
#    overfits. One Bidirectional layer is still a legitimate capacity
#    increase (you have the full window at inference time, so there's no
#    reason to withhold the backward pass), just not stacked twice.
# 4. **Kept dropout modest (0.2) and did NOT add L2 on top of it.** Per the
#    "don't stack regularizers defensively" rule — add L2 only if this run
#    *still* shows a clear overfitting gap; adding it preemptively risks
#    pushing back into underfitting the way BatchNorm+L2+Bidirectional all
#    at once did last time.
#
# **Test this as one change-set against your baseline**, then if you want to
# push further, adjust ONE thing at a time from here (e.g. try adding
# LayerNormalization back in, or a second Bidirectional layer) so you can
# tell what actually moved the number.
#
# ## Realistic expectation
#
# Published FD001 benchmarks (capped RUL, RMSE-based) sit around RMSE 11-14,
# which is roughly R² 0.85-0.92. That's the realistic ceiling to aim for —
# not 0.96-0.98, which on this dataset usually signals a leakage or
# target-mismatch bug rather than a genuinely better model.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ReduceLROnPlateau,
    ModelCheckpoint
)

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
RANDOM_SEED = 42

# Setting random seeds for reproducibility
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

WINDOW_SIZE_EXPECTED = 30
NUMBER_OF_FEATURES_EXPECTED = 18  # constant sensors removed (24 - 6)

# %% [markdown]
# ## Data paths (CHANGED)
#
# Switched from `(not_removed_the_sensor)` to `(removed_the_sensor)` — these
# sequences also now carry the capped RUL target once you've re-run
# `calculate_rul.ipynb` → `spliting_data.ipynb` → `03_Feature_Scaling.ipynb`
# → `create_sequence.py` in that order.

# %%
X_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "X_train_sequences(removed_the_sensor).npy"
)

Y_TRAIN_PATH = (
    "../CMAPSSData/Processed/"
    "y_train_sequences(removed_the_sensor).npy"
)

X_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "X_val_sequences(removed_the_sensor).npy"
)

Y_VAL_PATH = (
    "../CMAPSSData/Processed/"
    "y_val_sequences(removed_the_sensor).npy"
)

# %%
BEST_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_best.keras"
)

FINAL_MODEL_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_final.keras"
)

HISTORY_PATH = (
    "../Models/Reduced_Sensor_Capped/"
    "LSTM_FD001_reduced_capped_history.npz"
)

# %%
X_train = np.load(X_TRAIN_PATH)
y_train = np.load(Y_TRAIN_PATH)

X_val = np.load(X_VAL_PATH)
y_val = np.load(Y_VAL_PATH)


print("\nTraining data:")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

print("\nValidation data:")
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)
# Out:
# Training data:
# X_train shape: (13818, 30, 18)
# y_train shape: (13818,)
#
# Validation data:
# X_val shape: (3913, 30, 18)
# y_val shape: (3913,)

# %%
print("\nX_train dtype:", X_train.dtype)
print("y_train dtype:", y_train.dtype)

print("\nX_train minimum:", X_train.min())
print("X_train maximum:", X_train.max())

print("\ny_train minimum:", y_train.min())
print("y_train maximum:", y_train.max())

assert y_train.max() <= 125, (
    "y_train max exceeds 125 -- RUL capping was not applied "
    "upstream. Re-run calculate_rul.ipynb through create_sequence.py."
)
# Out:
# X_train dtype: float32
# y_train dtype: float32
#
# X_train minimum: 0.0
# X_train maximum: 1.0
#
# y_train minimum: 0.0
# y_train maximum: 125.0

# %%
print("DATA VALIDATION")

if X_train.ndim != 3:
    raise ValueError(
        f"X_train must be 3-dimensional. "
        f"Found shape: {X_train.shape}"
    )

if X_val.ndim != 3:
    raise ValueError(
        f"X_val must be 3-dimensional. "
        f"Found shape: {X_val.shape}"
    )

window_size = X_train.shape[1]

if window_size != WINDOW_SIZE_EXPECTED:
    print(
        f"\nWARNING: Expected window size "
        f"{WINDOW_SIZE_EXPECTED}, "
        f"but found {window_size}."
    )

number_of_features = X_train.shape[2]

if number_of_features != NUMBER_OF_FEATURES_EXPECTED:
    print(
        f"\nWARNING: Expected {NUMBER_OF_FEATURES_EXPECTED} features "
        f"(constant sensors removed), but found {number_of_features}. "
        f"Check you loaded the (removed_the_sensor) files."
    )

if X_val.shape[2] != number_of_features:
    raise ValueError(
        "Training and validation datasets have "
        "different numbers of features."
    )

if len(X_train) != len(y_train):
    raise ValueError(
        "X_train and y_train have different "
        "numbers of samples."
    )

if len(X_val) != len(y_val):
    raise ValueError(
        "X_val and y_val have different "
        "numbers of samples."
    )

print("\nNaN values:")

print("X_train:", np.isnan(X_train).sum())
print("y_train:", np.isnan(y_train).sum())
print("X_val:", np.isnan(X_val).sum())
print("y_val:", np.isnan(y_val).sum())


print("\nInfinite values:")

print("X_train:", np.isinf(X_train).sum())
print("y_train:", np.isinf(y_train).sum())
print("X_val:", np.isinf(X_val).sum())
print("y_val:", np.isinf(y_val).sum())


if (
    np.isnan(X_train).any()
    or np.isnan(y_train).any()
    or np.isnan(X_val).any()
    or np.isnan(y_val).any()
):
    raise ValueError("NaN values detected in the dataset.")

if (
    np.isinf(X_train).any()
    or np.isinf(y_train).any()
    or np.isinf(X_val).any()
    or np.isinf(y_val).any()
):
    raise ValueError(
        "Infinite values detected in the dataset."
    )
# Out:
# DATA VALIDATION
#
# NaN values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0
#
# Infinite values:
# X_train: 0
# y_train: 0
# X_val: 0
# y_val: 0

# %%
print("INPUT INFORMATION")

print("\nWindow size:", window_size)
print("Number of features:", number_of_features)
print(
    "Input shape:",
    X_train.shape[1:]
)

print("\nTraining samples:", len(X_train))
print("Validation samples:", len(X_val))


print("\nTraining RUL range:")
print("Minimum:", y_train.min())
print("Maximum:", y_train.max())

print("\nValidation RUL range:")
print("Minimum:", y_val.min())
print("Maximum:", y_val.max())
# Out:
# INPUT INFORMATION
#
# Window size: 30
# Number of features: 18
# Input shape: (30, 18)
#
# Training samples: 13818
# Validation samples: 3913
#
# Training RUL range:
# Minimum: 0.0
# Maximum: 125.0
#
# Validation RUL range:
# Minimum: 0.0
# Maximum: 125.0

# %% [markdown]
# ## Model architecture (CHANGED)
#
# Single `Bidirectional(LSTM(64))` (not two stacked), no `BatchNormalization`,
# moderate `Dropout(0.2)` between layers, no L2. ~half the parameter count of
# the previous 344K-param version, sized more sensibly for 13.8K training
# sequences.

# %%
print("Building LSTM Model")

INPUT_SHAPE = X_train.shape[1:]

model = Sequential([
    Input(shape=INPUT_SHAPE),

    Bidirectional(
        LSTM(64, return_sequences=True)
    ),
    Dropout(0.2),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(16, activation="relu"),
    Dense(1)
])
# Out:
# Building LSTM Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print("LSTM Model Architecture")
model.summary()
# Out:
# LSTM Model Architecture
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 30, 128)        │        42,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 63,649 (248.63 KB)
#  Trainable params: 63,649 (248.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("SETTING TRAINING CALLBACKS")

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=12,
    mode='min',
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    mode='min',
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    BEST_MODEL_PATH,
    monitor="val_loss",
    mode="min",
    save_best_only=True,
    verbose=1
)
# Out:
# SETTING TRAINING CALLBACKS

# %%
print("STARTING LSTM TRAINING")

history = model.fit(
    X_train, y_train,
    validation_data=(
        X_val,
        y_val
    ),
    epochs=100,
    batch_size=64,
    callbacks=[
        early_stopping,
        reduce_lr,
        model_checkpoint
    ],
    verbose=1
)
# Out:
# STARTING LSTM TRAINING
# Epoch 1/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5462.1919 - mae: 62.9465
# Epoch 1: val_loss improved from None to 3421.69043, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 1: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - loss: 5428.6826 - mae: 62.7279 - val_loss: 3421.6904 - val_mae: 50.9615 - learning_rate: 0.0010
# Epoch 2/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2115.7708 - mae: 40.3922
# Epoch 2: val_loss improved from 3421.69043 to 1829.33667, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 2: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 2114.5161 - mae: 40.3838 - val_loss: 1829.3367 - val_mae: 38.7229 - learning_rate: 0.0010
# Epoch 3/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1786.9716 - mae: 37.3733
# Epoch 3: val_loss improved from 1829.33667 to 1786.45483, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 3: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 1788.9060 - mae: 37.3904 - val_loss: 1786.4548 - val_mae: 38.1339 - learning_rate: 0.0010
# Epoch 4/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1777.0841 - mae: 37.2958
# Epoch 4: val_loss improved from 1786.45483 to 1785.99927, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 4: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 1779.3577 - mae: 37.3196 - val_loss: 1785.9993 - val_mae: 38.1267 - learning_rate: 0.0010
# Epoch 5/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1783.1464 - mae: 37.2772
# Epoch 5: val_loss improved from 1785.99927 to 1784.50439, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 5: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 1785.0781 - mae: 37.2944 - val_loss: 1784.5044 - val_mae: 38.1025 - learning_rate: 0.0010
# Epoch 6/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1522.7218 - mae: 34.4119
# Epoch 6: val_loss improved from 1784.50439 to 878.97894, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 6: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 1514.0117 - mae: 34.3038 - val_loss: 878.9789 - val_mae: 26.7493 - learning_rate: 0.0010
# Epoch 7/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 770.2087 - mae: 22.5861
# Epoch 7: val_loss improved from 878.97894 to 519.99365, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 7: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 767.0623 - mae: 22.5397 - val_loss: 519.9937 - val_mae: 19.6037 - learning_rate: 0.0010
# Epoch 8/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 401.0373 - mae: 15.7245
# Epoch 8: val_loss improved from 519.99365 to 313.26874, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 8: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 400.4943 - mae: 15.7079 - val_loss: 313.2687 - val_mae: 14.2183 - learning_rate: 0.0010
# Epoch 9/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 302.3039 - mae: 13.3248
# Epoch 9: val_loss improved from 313.26874 to 235.50667, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 9: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 301.8311 - mae: 13.3167 - val_loss: 235.5067 - val_mae: 12.3738 - learning_rate: 0.0010
# Epoch 10/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 272.8770 - mae: 12.5335
# Epoch 10: val_loss improved from 235.50667 to 223.87950, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 10: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 272.2756 - mae: 12.5209 - val_loss: 223.8795 - val_mae: 11.5967 - learning_rate: 0.0010
# Epoch 11/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 261.2498 - mae: 12.1753
# Epoch 11: val_loss improved from 223.87950 to 222.64006, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 11: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 261.2498 - mae: 12.1753 - val_loss: 222.6401 - val_mae: 11.5541 - learning_rate: 0.0010
# Epoch 12/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 249.8101 - mae: 11.8623
# Epoch 12: val_loss improved from 222.64006 to 219.68913, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 12: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 249.1276 - mae: 11.8478 - val_loss: 219.6891 - val_mae: 11.4460 - learning_rate: 0.0010
# Epoch 13/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 244.4516 - mae: 11.7212
# Epoch 13: val_loss improved from 219.68913 to 195.11829, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 13: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 244.4516 - mae: 11.7212 - val_loss: 195.1183 - val_mae: 10.8838 - learning_rate: 0.0010
# Epoch 14/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 243.6164 - mae: 11.7022
# Epoch 14: val_loss did not improve from 195.11829
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 243.5200 - mae: 11.6971 - val_loss: 197.0040 - val_mae: 10.8135 - learning_rate: 0.0010
# Epoch 15/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 239.4176 - mae: 11.5197
# Epoch 15: val_loss improved from 195.11829 to 191.91992, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 15: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 238.9867 - mae: 11.5096 - val_loss: 191.9199 - val_mae: 10.5078 - learning_rate: 0.0010
# Epoch 16/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 242.0810 - mae: 11.5711
# Epoch 16: val_loss did not improve from 191.91992
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 241.8857 - mae: 11.5660 - val_loss: 210.6765 - val_mae: 11.0323 - learning_rate: 0.0010
# Epoch 17/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 238.3517 - mae: 11.5279
# Epoch 17: val_loss did not improve from 191.91992
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 238.3517 - mae: 11.5279 - val_loss: 198.7767 - val_mae: 10.4354 - learning_rate: 0.0010
# Epoch 18/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 234.1423 - mae: 11.3854
# Epoch 18: val_loss improved from 191.91992 to 184.37860, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 18: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 233.8954 - mae: 11.3794 - val_loss: 184.3786 - val_mae: 10.0795 - learning_rate: 0.0010
# Epoch 19/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 229.4910 - mae: 11.2791
# Epoch 19: val_loss improved from 184.37860 to 181.92917, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 19: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 228.9246 - mae: 11.2673 - val_loss: 181.9292 - val_mae: 10.1833 - learning_rate: 0.0010
# Epoch 20/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 232.0834 - mae: 11.2736
# Epoch 20: val_loss did not improve from 181.92917
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 232.0834 - mae: 11.2736 - val_loss: 202.7090 - val_mae: 10.6176 - learning_rate: 0.0010
# Epoch 21/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 225.3098 - mae: 11.1852
# Epoch 21: val_loss did not improve from 181.92917
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 224.8890 - mae: 11.1768 - val_loss: 205.1496 - val_mae: 10.7443 - learning_rate: 0.0010
# Epoch 22/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 230.0363 - mae: 11.2725
# Epoch 22: val_loss improved from 181.92917 to 179.45752, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 22: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 229.6589 - mae: 11.2611 - val_loss: 179.4575 - val_mae: 9.7289 - learning_rate: 0.0010
# Epoch 23/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 224.6420 - mae: 11.1137
# Epoch 23: val_loss improved from 179.45752 to 177.99757, saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
#
# Epoch 23: finished saving model to ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 224.4972 - mae: 11.1086 - val_loss: 177.9976 - val_mae: 10.0069 - learning_rate: 0.0010
# Epoch 24/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 219.6463 - mae: 10.9704
# Epoch 24: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 219.6463 - mae: 10.9704 - val_loss: 192.8374 - val_mae: 10.3830 - learning_rate: 0.0010
# Epoch 25/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 223.6418 - mae: 11.1106
# Epoch 25: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 223.6418 - mae: 11.1106 - val_loss: 197.8937 - val_mae: 10.6164 - learning_rate: 0.0010
# Epoch 26/100
# 214/216 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 219.7993 - mae: 10.9691
# Epoch 26: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 219.6314 - mae: 10.9663 - val_loss: 197.3165 - val_mae: 10.5787 - learning_rate: 0.0010
# Epoch 27/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 222.1138 - mae: 11.0246
# Epoch 27: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - loss: 222.0558 - mae: 11.0212 - val_loss: 184.4472 - val_mae: 10.2001 - learning_rate: 0.0010
# Epoch 28/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 218.5616 - mae: 10.9097
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 28: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 218.5616 - mae: 10.9097 - val_loss: 195.0111 - val_mae: 10.5101 - learning_rate: 0.0010
# Epoch 29/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 207.8172 - mae: 10.6217
# Epoch 29: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 207.8172 - mae: 10.6217 - val_loss: 189.4497 - val_mae: 10.2048 - learning_rate: 5.0000e-04
# Epoch 30/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 209.8786 - mae: 10.6434
# Epoch 30: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 209.5324 - mae: 10.6366 - val_loss: 193.8492 - val_mae: 10.3479 - learning_rate: 5.0000e-04
# Epoch 31/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 205.4339 - mae: 10.5756
# Epoch 31: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 205.0950 - mae: 10.5673 - val_loss: 204.7309 - val_mae: 10.7581 - learning_rate: 5.0000e-04
# Epoch 32/100
# 213/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 205.6841 - mae: 10.5559
# Epoch 32: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 205.4795 - mae: 10.5531 - val_loss: 195.9868 - val_mae: 10.4374 - learning_rate: 5.0000e-04
# Epoch 33/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 206.1506 - mae: 10.5608
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 33: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 206.1506 - mae: 10.5608 - val_loss: 197.2132 - val_mae: 10.5353 - learning_rate: 5.0000e-04
# Epoch 34/100
# 215/216 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 200.1429 - mae: 10.3873
# Epoch 34: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 199.8448 - mae: 10.3817 - val_loss: 193.5182 - val_mae: 10.3241 - learning_rate: 2.5000e-04
# Epoch 35/100
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 195.7276 - mae: 10.2717
# Epoch 35: val_loss did not improve from 177.99757
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 195.7276 - mae: 10.2717 - val_loss: 188.3935 - val_mae: 10.1542 - learning_rate: 2.5000e-04
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 23.

# %%
model.save(FINAL_MODEL_PATH)

print("MODEL TRAINING COMPLETED")

print("\nFinal model saved at:")
print(FINAL_MODEL_PATH)

print("\nBest model saved at:")
print(BEST_MODEL_PATH)
# Out:
# MODEL TRAINING COMPLETED
#
# Final model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_final.keras
#
# Best model saved at:
# ../Models/Reduced_Sensor_Capped/LSTM_FD001_reduced_capped_best.keras

# %%
np.savez(
    HISTORY_PATH,

    loss=np.array(
        history.history["loss"]
    ),

    val_loss=np.array(
        history.history["val_loss"]
    ),

    mae=np.array(
        history.history["mae"]
    ),

    val_mae=np.array(
        history.history["val_mae"]
    )
)

# %%
print("TRAINING INFORMATION")

print("Total epochs requested", 100)
print("Actual epochs completed:", len(history.history['loss']))
print("Best validation loss:", min(history.history["val_loss"]))
print("Best validation MAE:", min(history.history["val_mae"]))

# Overfitting check: compare final train vs val MAE directly
final_train_mae = history.history['mae'][-1]
final_val_mae = history.history['val_mae'][-1]
gap = final_val_mae - final_train_mae
print(f"\nFinal train MAE: {final_train_mae:.3f}")
print(f"Final val MAE:   {final_val_mae:.3f}")
print(f"Train/val gap:   {gap:.3f} cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)")
# Out:
# TRAINING INFORMATION
# Total epochs requested 100
# Actual epochs completed: 35
# Best validation loss: 177.99757385253906
# Best validation MAE: 9.728882789611816
#
# Final train MAE: 10.272
# Final val MAE:   10.154
# Train/val gap:   -0.117 cycles (rule of thumb: >5 cycles gap on this scale suggests real overfitting)

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["loss"], label="Training Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training vs Validation Loss")

plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(history.history["mae"], label="Training MAE")

plt.plot(history.history["val_mae"], label="Validation MAE")

plt.xlabel("Epoch")
plt.ylabel("MAE (Cycles)")
plt.title("Training vs Validation MAE")

plt.legend()
plt.grid(True)

plt.tight_layout()

plt.show()

# %%
print("VALIDATION PREDICTION")

y_pred = model.predict(
    X_val,
    verbose=1
)

y_pred = y_pred.reshape(-1)

mae = mean_absolute_error(y_val, y_pred)

mse = mean_squared_error(y_val, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_val, y_pred)
# Out:
# VALIDATION PREDICTION
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
print("VALIDATION PERFORMANCE")

print(f"\nMAE : {mae:.4f} cycles")

print(f"RMSE  : {rmse:.4f} cycles")

print(f"R²    : {r2:.4f}")
# Out:
# VALIDATION PERFORMANCE
#
# MAE : 10.0069 cycles
# RMSE  : 13.3416 cycles
# R²    : 0.8983

# %%
plt.figure(figsize=(10, 6))

plt.scatter(y_val, y_pred, alpha=0.5)

# Perfect prediction line

minimum = min(y_val.min(), y_pred.min())

maximum = max(y_val.max(), y_pred.max())

plt.plot([minimum, maximum], [minimum, maximum], linestyle="--")

plt.xlabel("Actual RUL")
plt.ylabel("Predicted RUL")

plt.title("Actual RUL vs Predicted RUL")

plt.grid(True)

plt.tight_layout()

plt.show()

# %%
number_to_plot = min(300, len(y_val))

plt.figure(figsize=(12, 6))

plt.plot(y_val[:number_to_plot], label="Actual RUL")

plt.plot(y_pred[:number_to_plot], label="Predicted RUL")

plt.xlabel("Validation Sample")
plt.ylabel("RUL (Cycles)")

plt.title("Actual vs Predicted RUL on Validation Data")

plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print("FINAL SUMMARY")

print("""
Experiment:
    Constant sensors removed, RUL capped at 125

Model:
    Bidirectional(LSTM(64))
    Dropout(0.20)
    LSTM(32)
    Dropout(0.20)
    Dense(16, ReLU)
    Dense(1)

Optimizer:
    Adam

Initial learning rate:
    0.001

Loss:
    MSE

Training metric:
    MAE

Maximum epochs:
    100

Batch size:
    64

Callbacks:
    EarlyStopping
    ReduceLROnPlateau
    ModelCheckpoint
""")

print(f"Validation MAE  : {mae:.4f} cycles")

print(f"Validation RMSE : {rmse:.4f} cycles")

print(f"Validation R²   : {r2:.4f}")

print("\nTraining completed successfully.")
# Out:
# FINAL SUMMARY
#
# Experiment:
#     Constant sensors removed, RUL capped at 125
#
# Model:
#     Bidirectional(LSTM(64))
#     Dropout(0.20)
#     LSTM(32)
#     Dropout(0.20)
#     Dense(16, ReLU)
#     Dense(1)
#
# Optimizer:
#     Adam
#
# Initial learning rate:
#     0.001
#
# Loss:
#     MSE
#
# Training metric:
#     MAE
#
# Maximum epochs:
#     100
#
# Batch size:
#     64
#
# Callbacks:
#     EarlyStopping
#     ReduceLROnPlateau
#     ModelCheckpoint
#
# Validation MAE  : 10.0069 cycles
# Validation RMSE : 13.3416 cycles
# Validation R²   : 0.8983
#
# Training completed successfully.
